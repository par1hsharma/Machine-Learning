# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img_top_left=cv2.imread('/Users/parthsharma/Desktop/Data Science CD/ImageCollage dataset/top_left.jpg')
rgb_top_left=cv2.cvtColor(img_top_left,cv2.COLOR_BGR2RGB)
print(img.shape)
# Out:
# (570, 570, 3)

# %%
plt.imshow(img)

# %%
resize_top_left=cv2.resize(rgb_top_left,(200,200))
resize_top_left.shape
# Out:
# (200, 200, 3)

# %%
plt.imshow(resize_top_left)
